# %%
# %matplotlib notebook

# %%
import pandas
activity = pandas.read_csv("../processed/activity_features_aggregate.txt", index_col=0, sep="\t")
ukbb = pandas.read_csv("../processed/ukbb_data_table.txt", index_col=0, sep="\t")

# %%
ukbb.describe()
# Out:
#        education_Prefer_not_to_answer  education_None_of_the_above  \
# count                   497886.000000                497886.000000
# mean                         0.011033                     0.171274
# std                          0.104455                     0.376749
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     0.000000
# max                          1.000000                     1.000000
#
#        education_College_or_University_degree  \
# count                           497886.000000
# mean                                 0.323711
# std                                  0.467892
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  1.000000
# max                                  1.000000
#
#        education_A_levels/AS_levels_or_equivalent  \
# count                               497886.000000
# mean                                     0.261540
# std                                      0.439474
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      1.000000
# max                                      1.000000
#
#        education_O_levels/GCSEs_or_equivalent  education_CSEs_or_equivalent  \
# count                           497886.000000                 497886.000000
# mean                                 0.450961                      0.129572
# std                                  0.497590                      0.335832
# min                                  0.000000                      0.000000
# 25%                                  0.000000                      0.000000
# 50%                                  0.000000                      0.000000
# 75%                                  1.000000                      0.000000
# max                                  1.000000                      1.000000
#
#        education_NVQ_or_HND_or_HNC_or_equivalent  \
# count                              497886.000000
# mean                                    0.182785
# std                                     0.386490
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        education_Other_professional_qualifications_eg:_nursing,_teaching  \
# count                                      497886.000000
# mean                                            0.279761
# std                                             0.448882
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        medication_cholesterol_bp_diabetes_Do_not_know  \
# count                                   226945.000000
# mean                                         0.009196
# std                                          0.095454
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        medication_cholesterol_bp_diabetes_Prefer_not_to_answer  ...  \
# count                                      226945.000000        ...
# mean                                            0.001410        ...
# std                                             0.037524        ...
# min                                             0.000000        ...
# 25%                                             0.000000        ...
# 50%                                             0.000000        ...
# 75%                                             0.000000        ...
# max                                             1.000000        ...
#
#                  BMI  hip_circumference  waist_circumference         weight  \
# count  499423.000000      500309.000000        500368.000000  499754.000000
# mean       27.432664         103.401652            90.310918      78.054660
# std         4.803095           9.249566            13.485857      15.945757
# min        12.121200          30.000000            20.000000      30.000000
# 25%        24.138900          97.000000            80.000000      66.500000
# 50%        26.743300         102.000000            90.000000      76.400000
# 75%        29.908400         108.000000            99.000000      87.500000
# max        74.683700         195.000000           197.000000     197.700000
#
#        age_bilateral_oophorectomy  age_hysterectomy  age_menopause  \
# count                21198.000000      49854.000000   154630.00000
# mean                    47.446363         43.928070       49.66436
# std                      7.773400          8.037897        5.14153
# min                     10.000000         10.000000       18.00000
# 25%                     43.000000         39.000000       47.00000
# 50%                     48.000000         44.000000       50.00000
# 75%                     52.000000         49.000000       53.00000
# max                     69.000000         69.000000       68.00000
#
#        age_last_HRT  age_start_HRT  age_periods_started
# count  93776.000000   93226.000000        264542.000000
# mean      42.534646      47.376719            12.969816
# std       25.272923       5.445444             1.623211
# min      -11.000000      16.000000             5.000000
# 25%       46.000000      45.000000            12.000000
# 50%       53.000000      48.000000            13.000000
# 75%       57.000000      51.000000            14.000000
# max       70.000000      70.000000            25.000000
#
# [8 rows x 45 columns]

# %%
data = activity.copy()
data['oestradiol'] = data.index.map(ukbb.oestradiol)
data['testosterone'] = data.index.map(ukbb.testosterone)
data['sex'] = data.index.map(ukbb.sex)
data['birth_year'] = data.index.map(ukbb.birth_year)
data['age_menopause'] = data.index.map(ukbb.age_menopause)
data['had_menopause'] = ~data['age_menopause'].isna()
data['HRT_ever'] = ~data.index.map(ukbb.age_start_HRT).isna()
data['HRT_stopped'] = ~data.index.map(ukbb.age_last_HRT).isna() | (data.index.map(ukbb.age_last_HRT) == -11)
data['HRT'] = pandas.Categorical(data.HRT_ever.astype(str).str.cat(data.HRT_stopped.astype(str)))
data['birth_month'] = data.index.map(ukbb.birth_month)

# %%
# Down sample for testing
import numpy
numpy.random.seed(0)
selected_ids = numpy.random.choice(data.index, size=(10_000))
data = data.loc[selected_ids]

# %%
import pylab
pylab.scatter(data.oestradiol, data.main_sleep_duration_avg, s=0.3)
pylab.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns
sns.lmplot(x="oestradiol", y="main_sleep_duration_avg", data=data, hue="sex")
# Out:
# <img src="data:image/png;base64,..." width="601">

# %%
sns.lmplot(y="oestradiol", x="birth_year", data=data[data.sex=="Female"], hue="HRT_stopped")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-73be58733711> in <module>
# ----> 1 sns.lmplot(y="oestradiol", x="birth_year", data=data[data.sex=="Female"], hue=["HRT_stopped", "HRT"])
#
# c:\users\tgb\data\ukbb\scripts\venv\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     548     # Reduce the dataframe to only needed columns
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
# --> 550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
#     551     data = data[cols]
#     552
#
# c:\users\tgb\data\ukbb\scripts\venv\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     ar = np.asanyarray(ar)
#     263     if axis is None:
# --> 264         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     265         return _unpack_tuple(ret)
#     266
#
# c:\users\tgb\data\ukbb\scripts\venv\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310         aux = ar[perm]
#     311     else:
# --> 312         ar.sort()
#     313         aux = ar
#     314     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'list' and 'str'

# %%
(~data.HRT & data.had_menopause).sum()
# Out:
# 18681

# %%
sns.lmplot(x="birth_year", y="WASO_avg", hue="HRT", data=data[data.sex == "Female"])
# Out:
# <img src="data:image/png;base64,..." width="622">
